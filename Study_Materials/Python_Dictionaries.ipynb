# %% [markdown]
# # Dictionary
#
# Dictionary in Python is a collection of keys values, used to store data values like a map, which, unlike other data types which hold only a single value as an element.
#
# In some languages it is known as map or assosiative arrays.
#
# dict = { 'name' : 'Tahmoor' , 'age' : 19 , 'gender' : 'male' }
#
# Characterstics:
#
# - Mutable
# - Indexing has no meaning
# - keys can't be duplicated
# - keys can't be mutable items

# %% [markdown]
# ### Create Dictionary

# %%
# empty dictionary
d = {}
d
# 1D dictionary
d1 = { 'name' : 'Ghazanfar' ,'gender' : 'male' }
d1
# with mixed keys
d2 = {(1,2,3):1,'hello':'world'}
d2[(1,2,3)]
# Out:
# 1

# %%
# 2D dictionary -> JSON
s = {
    'name':'Ghazanfar',
     'University':'UMT',
     'sem':3,
     'subjects':{
         'dsa':87,
         'maths':77,
         'english':89
     }
}
s
# using sequence and dict function
d4 = dict([('name','Imran'),('age',19),(3,3)])
d4
# duplicate keys
d5 = {'name':'Ahmed','name':'Imran'}
d5
# mutable items as keys
#d6 = {'name':'Tahmoor',(1,2,3):2}
#print(d6)
# Out:
# {'name': 'Tahmoor', (1, 2, 3): 2}

# %% [markdown]
# ### Accessing items

# %%
my_dict = {'name': 'Kashif', 'age': 26}
# []
my_dict['age']
# get
my_dict.get('age')
#s
#s['subjects']['maths']

# %% [markdown]
# ### Adding key-value pair

# %%
d4['gender'] = 'male'
d4
d4['weight'] = 72
d4

s['subjects']['ds'] = 75
s

# %% [markdown]
# ### Remove key-value pair

# %%
d = {'name': 'Imran', 'age': 19, 3: 3, 'gender': 'male', 'weight': 72}
# pop
#d.pop(3)
#print(d)
# popitem
#d.popitem()
# d.popitem()
# print(d)
# del
#del d['name']
#print(d)
# clear
d.clear()
print(d)

del s['subjects']['maths']
s

# %% [markdown]
# ### Editing key-value pair

# %%
s['subjects']['dsa'] = 80
s

# %% [markdown]
# ### Dictionary Operations
#
# - Membership
# - Iteration

# %%
print(s)

'name' in s
# Out:
# {'name': 'Ghazanfar', 'University': 'UMT', 'sem': 3, 'subjects': {'dsa': 80, 'maths': 77, 'english': 89}}
# True

# %%
d = {'name':'Tahmoor','gender':'male','age':19}

for i in d:
  print(i)
  #print(i,d[i])

# %% [markdown]
# ### Dictionary Functions

# %%
# len/sorted
len(d)
print(d)
sorted(d,reverse=True)
max(d)

# %%
# items/keys/values
print(d)

print(d.items())
print(d.keys())
print(d.values())

# %%
# update
d1 = {1:2,3:4,4:5}
d2 = {4:7,6:8}

d1.update(d2)
print(d1)

# %% [markdown]
# ### Dictionary Comprehension
# ![Python-dictionary-comprehension.webp](data:image/webp;base64,...)

# %%
# print 1st 10 numbers and their squares
{num:num**2 for num in range(1,11)}

# %%
distances = {'Karachi':1000,'Lahore':2000,'Islam Abad':3000}
print(distances.items())

# %%
# using existing dict
distances = {'Karachi':1000,'Lahore':2000,'Islam Abad':3000}
{key:value*0.62 for (key,value) in distances.items()}

# %%
# using zip
days = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday", "Sunday"]
temp_C = [38.5,39.6,37.8,37.4,40.8,40.2,39.9]

{i:j for (i,j) in zip(days,temp_C)}

# %%
# using if condition
products = {'phone':10,'laptop':0,'charger':32,'tablet':0}

{key:value for (key,value) in products.items() if value>0}

# %%
# Nested Comprehension
# print tables of number from 2 to 4
{i:{j:i*j for j in range(1,11)} for i in range(2,5)}
